# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("Hargovind - Sheet2.csv")

# %%
dataset
# Out:
#       Bill Date Tran Type Bill Prefix  Bill No  Customer Code  \
# 0    01/02/2020    Return      W49R19      4.0   9.198114e+11
# 2    01/02/2020     Sales      W49S19    111.0   9.198101e+11
# 3    01/02/2020     Sales      W49S19    111.0   9.198101e+11
# 4    01/02/2020     Sales      W49S19    112.0   9.198101e+11
# 5    01/02/2020     Sales      W49S19    113.0   9.198101e+11
# ..          ...       ...         ...      ...            ...
# 152  01/12/2020     Sales      W49S20    693.0   9.199716e+11
# 153  01/12/2020     Sales      W49S20    694.0   9.199716e+11
# 154  01/12/2020     Sales      W49S20    695.0   9.199000e+11
# 155  01/12/2020     Sales      W49S20    696.0   9.192127e+11
# 156  01/12/2020     Sales      W49S20    696.0   9.192127e+11
#
#          Customer Name Sales Man Code       Item Promo Code Bill Promo Code  \
# 0       Pradeep Sharma        RH07117  HO-30-W49-TRS-190120             NaN
# ...

# %%
index_to_drop = dataset.index[dataset["Bill Date"].str.contains("Sub")].to_list()

# %%
for i in index_to_drop:
    dataset = dataset.drop(i)

# %%
dataset
# Out:
#       Bill Date Tran Type Bill Prefix  Bill No  Customer Code  \
# 0    01/02/2020    Return      W49R19      4.0   9.198114e+11
# 2    01/02/2020     Sales      W49S19    111.0   9.198101e+11
# 3    01/02/2020     Sales      W49S19    111.0   9.198101e+11
# 4    01/02/2020     Sales      W49S19    112.0   9.198101e+11
# 5    01/02/2020     Sales      W49S19    113.0   9.198101e+11
# ..          ...       ...         ...      ...            ...
# 152  01/12/2020     Sales      W49S20    693.0   9.199716e+11
# 153  01/12/2020     Sales      W49S20    694.0   9.199716e+11
# 154  01/12/2020     Sales      W49S20    695.0   9.199000e+11
# 155  01/12/2020     Sales      W49S20    696.0   9.192127e+11
# 156  01/12/2020     Sales      W49S20    696.0   9.192127e+11
#
#          Customer Name Sales Man Code       Item Promo Code Bill Promo Code  \
# 0       Pradeep Sharma        RH07117  HO-30-W49-TRS-190120             NaN
# ...

# %%
dataset.reset_index(drop=True)
# Out:
#       Bill Date Tran Type Bill Prefix  Bill No  Customer Code  \
# 0    01/02/2020    Return      W49R19      4.0   9.198114e+11
# 1    01/02/2020     Sales      W49S19    111.0   9.198101e+11
# 2    01/02/2020     Sales      W49S19    111.0   9.198101e+11
# 3    01/02/2020     Sales      W49S19    112.0   9.198101e+11
# 4    01/02/2020     Sales      W49S19    113.0   9.198101e+11
# ..          ...       ...         ...      ...            ...
# 132  01/12/2020     Sales      W49S20    693.0   9.199716e+11
# 133  01/12/2020     Sales      W49S20    694.0   9.199716e+11
# 134  01/12/2020     Sales      W49S20    695.0   9.199000e+11
# 135  01/12/2020     Sales      W49S20    696.0   9.192127e+11
# 136  01/12/2020     Sales      W49S20    696.0   9.192127e+11
#
#          Customer Name Sales Man Code       Item Promo Code Bill Promo Code  \
# 0       Pradeep Sharma        RH07117  HO-30-W49-TRS-190120             NaN
# ...

# %%
dataset.drop(columns=["Old Bill Ref."])
# Out:
#       Bill Date Tran Type Bill Prefix  Bill No  Customer Code  \
# 0    01/02/2020    Return      W49R19      4.0   9.198114e+11
# 2    01/02/2020     Sales      W49S19    111.0   9.198101e+11
# 3    01/02/2020     Sales      W49S19    111.0   9.198101e+11
# 4    01/02/2020     Sales      W49S19    112.0   9.198101e+11
# 5    01/02/2020     Sales      W49S19    113.0   9.198101e+11
# ..          ...       ...         ...      ...            ...
# 152  01/12/2020     Sales      W49S20    693.0   9.199716e+11
# 153  01/12/2020     Sales      W49S20    694.0   9.199716e+11
# 154  01/12/2020     Sales      W49S20    695.0   9.199000e+11
# 155  01/12/2020     Sales      W49S20    696.0   9.192127e+11
# 156  01/12/2020     Sales      W49S20    696.0   9.192127e+11
#
#          Customer Name Sales Man Code       Item Promo Code Bill Promo Code  \
# 0       Pradeep Sharma        RH07117  HO-30-W49-TRS-190120             NaN
# ...

# %%
dataset.to_csv("cleandata.csv")
